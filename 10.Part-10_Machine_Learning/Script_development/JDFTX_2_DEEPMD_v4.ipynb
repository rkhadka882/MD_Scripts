# %%
#Importing the modules
import numpy as np
import dpdata
import os
import matplotlib.pyplot as plt

# %%
print("Note:\n\
---------------------------------------------------------------------------------------------\n\
> No. of atoms should be same in both NPT and NVT data\n\
> Combine the NPT and NVT AIMD runs separately for a given system, use combine_AIMD.sh\n\
> To execute: python JDFTX_2_DEEPMD_v4.py \n\
> Output: type.raw type_map.raw force.raw, energy.raw, coord.raw, box.raw which are shuffled\n\
> Use /deepmd-kit/data/raw/raw_2_set.sh to create multiple sets of data\n\
> This script assumes the following: \n\
>> NPT and NVT runs have same no. of atoms and same atom types only \n\
>> jdftx ionic position are dumped alphabetically for all ionic steps not random \n\
---------------------------------------------------------------------------------------------\n\
\n\
")
# Out:
# Note:
# ---------------------------------------------------------------------------------------------
# > No. of atoms should be same in both NPT and NVT data
# > Combine the NPT and NVT AIMD runs separately for a given system, use combine_AIMD.sh
# > To execute: python JDFTX_2_DEEPMD_v4.py
# > Output: type.raw type_map.raw force.raw, energy.raw, coord.raw, box.raw which are shuffled
# > Use /deepmd-kit/data/raw/raw_2_set.sh to create multiple sets of data
# > This script assumes the following:
# >> NPT and NVT runs have same no. of atoms and same atom types only
# >> jdftx ionic position are dumped alphabetically for all ionic steps not random
# ---------------------------------------------------------------------------------------------

# %%
os.system('ls')
# Out:
# CoSi_300k_AIMD - Copy.jdftxout
# CoSi_300k_AIMD.jdftxout
# CoSi_300k_NPT.jdftxout
# CoSi_AIMD
# CoSi_vacuum_300k.jdftxout
# Data_collection_script
# ipynb_version
# JDFTX_2_DEEPMD.ipynb
# JDFTX_2_DEEPMD_v1.py
# JDFTX_2_DEEPMD_v2.py
# JDFTX_2_DEEPMD_v2.txt
# JDFTX_2_DEEPMD_v3.py
# JDFTX_2_DEEPMD_v4.ipynb
# JDFTX_2_DEEPMD_v4.py
# md.o1065264
# Test
# training_data
# 0

# %%
# Asking user for cetrain inputs:

# Ask the user for a folder name
# folder = input("Enter the folder to put all data eg. CoSi_AIMD: ")
# frame_sep = input("Enter the frame separation in AIMD data eg. 10 :")
# file_AIMD = input("Enter the combined NPT filename eg. CoSi_AIMD.jdftxout: ")

folder = "Test"
frame_sep = 10
file_AIMD = "CoSi_300k_AIMD - Copy.jdftxout"

# Check if directory exists. If not, create it.
if not os.path.exists(folder):
    os.makedirs(folder)
    print(f"Folder '{folder}' has been created.")
else:
    print(f"Folder '{folder}' already exists.")
# Out:
# Folder 'Test' already exists.

# %%
atom_types = ['Co', 'Si', 'O']  # CHANGE HERE, Add the types of elements that you use 
                                # in your project even if certain datas has only few elements

# Conversion from jdftx to deepmd or lammps
ene_conv = 27.2114              # hartree to eV conversion
len_conv = 0.529177             # bohr to Angstrom conversion
force_conv = ene_conv/len_conv  # E = fd, so f = E/d 

# Single atom energies:
E_Co = -148.9280175 * ene_conv # hartree to eV
E_Si = -3.600491552 * ene_conv # hartree to eV
E_O = -15.72003172 * ene_conv # hartree to eV

# %%
# Function definitions:

def get_atoms_info(line):
    natoms = int(line.strip().split()[4])
    nspecies = int(line.strip().split()[1])
    return natoms, nspecies

def get_energy(line):
    return float(line.strip().split()[2])

def get_lattice_vectors(lines, i):
    x = list(map(float, lines[i].strip().replace('[', '').replace(']', '').split()))
    y = list(map(float, lines[i+1].strip().replace('[', '').replace(']', '').split()))
    z = list(map(float, lines[i+2].strip().replace('[', '').replace(']', '').split()))
    return x + y + z

def get_volume(line):
    return float(line.strip().split()[4])

def get_stress_tensor(lines, i, volume):
    x = list(map(float, lines[i].strip().replace('[', '').replace(']', '').split()))
    y = list(map(float, lines[i+1].strip().replace('[', '').replace(']', '').split()))
    z = list(map(float, lines[i+2].strip().replace('[', '').replace(']', '').split()))
    xx = [i*volume for i in x]
    yy = [i*volume for i in y]
    zz = [i*volume for i in z]
    return xx + yy + zz

def get_coordinates(lines, natoms, i):
    clines = lines[i:i+natoms]
    coord = np.array([list(map(float, line.strip().split()[2:5])) for line in clines]).reshape(-1)
    allatoms = [line.strip().split()[1] for line in clines]
    return coord, allatoms

def get_forces(lines, natoms, i):
    flines = lines[i:i+natoms]
    force = np.array([list(map(float, line.strip().split()[2:5])) for line in flines]).reshape(-1)
    return force

def automapping(allatoms):
    """
    Use the atom_types in the input and create type.raw
    and type_map.raw files
    """
    # Identifying unique atom types in the simulation:
    #atom_types = list(set(allatoms)); 

    # Assigning integer numbers to unique elements
    mapping = {atom: i for i, atom in enumerate(atom_types)}; 

    # Replacing elements with their mapping
    atm_mapped = [mapping[atom] for atom in allatoms]

    # Writing type_map.raw:
    with open("type.raw", 'w') as f:
        for value in atm_mapped:
            f.write(f"{value}\n")

    # Writing type.raw:
    with open("type_map.raw", 'w') as f:
        for i in atom_types:
            f.write(f"{i}\n")
    return atm_mapped

def all_convert(filename, frame_sep):
    """
    Collects the Force, enegy, box, virial datas from JDFTXoutput file
    """
    with open(filename) as file:
        lines = file.readlines()

        Etot, Force, Stress, Lattice, Coord = [], [], [], [], []

        for i, line in enumerate(lines):
            if "Initialized" in line:
                natoms, nspecies = get_atoms_info(line)
            if "Etot =    " in line:
                Etot.append(get_energy(line))
            if "# Lattice vectors:" in line:
                Lattice.append(get_lattice_vectors(lines, i+2))
            if "unit cell volume =" in line:
                volume = get_volume(line)
#             if "# Stress tensor in Cartesian coordinates" in line:
#                 Stress.append(get_stress_tensor(lines, i+1, volume))
            if "Ionic positions in cartesian coordinates" in line:
                coord, allatoms = get_coordinates(lines, natoms, i+1)
                Coord.append(coord)
            if "Forces in Cartesian coordinates" in line:
                Force.append(get_forces(lines, natoms, i+1))
    
    # Converting the list to array
    Etot = np.array(Etot)
    Lattice = np.array(Lattice)
    Coord = np.array(Coord)
    Force = np.array(Force)
    
    # Sampling the AIMD data:
    AIMD_frame_no = len(Etot) // frame_sep
    Frame_index = np.arange(AIMD_frame_no)*frame_sep

    Etot = Etot[Frame_index]
    Lattice = Lattice[Frame_index]
    Coord = Coord[Frame_index]
    Force = Force[Frame_index]

    # Shuffling the data:
    print(">Force, Energy, Coordinate, Lattice converted, shuffled, and saved")
    permuted_indices = np.random.permutation(len(Etot))
    Etot = np.array(Etot)[permuted_indices]*ene_conv
    Lattice = np.array(Lattice)[permuted_indices]*len_conv
    Coord = np.array(Coord)[permuted_indices]*len_conv
    Force = np.array(Force)[permuted_indices]*force_conv
#     Stress = np.array(Stress)[permuted_indices]*ene_conv
    
    # Energy correction:
    Etot = Etot - Energy_atom(allatoms)

    # Saving the data:
    np.savetxt("energy.raw", Etot)
    np.savetxt("box.raw", Lattice)
    np.savetxt("coord.raw", Coord)
    np.savetxt("force.raw", Force)
#     np.savetxt("virial.raw", Stress)
    
    return Etot, Force, Coord, Lattice, allatoms, natoms, nspecies

def Energy_atom(allatoms):
    """ Calculate the energy of atoms to be subtracted from bulk """
    # Assigning integer numbers to unique elements
    mapping = {atom: i for i, atom in enumerate(atom_types)}; 
    # Replacing elements with their mapping
    atm_mapped = [mapping[atom] for atom in allatoms]
    nCo = atm_mapped.count(0)
    nSi = atm_mapped.count(1)
    nO = atm_mapped.count(2)
    print('Co:', nCo, 'Si:', nSi,'O:', nO)
    E_atom = nCo*E_Co + nSi*E_Si + nO*E_O
    return E_atom

# %%
# AIMD Conversion:
print("!!!Converting the AIMD data!!!")
print('-'*50)

# Force, energy, virial, coord:
Etot_AIMD, Force_AIMD, Coord_AIMD, Lattice_AIMD, allatoms_AIMD, natoms, nspecies = all_convert(file_AIMD, frame_sep)

# Energy correction:
Etot_AIMD = Etot_AIMD - Energy_atom(allatoms_AIMD)

# type, type_map
atom_map_AIMD = automapping(allatoms_AIMD)

#---------------------------------------------------------------------------------------------

# Pringin the summary information:
print("# Summary of jdftx to DeepMD\n")
print('-'*50)
print("No. of Elements   :", nspecies)
print("Elements involved :", list(set(allatoms_AIMD)))
print("All Elements      :", atom_types)
# print("Element to int map:", mapping)
print("No. of atoms      :", natoms)
print("No. of frames     :", Force_AIMD.shape[0])
print("force.raw         :", Force_AIMD.shape)
print("coord.raw         :", Coord_AIMD.shape)
print("energy.raw        :", Etot_AIMD.shape)
print("box.raw           :", Lattice_AIMD.shape)
# print("virial.raw        :", Stress_AIMD.shape)
print('-'*50)
    
with open("conversionInfo.dat", 'w') as f:
    f.write("# Summary of jdftx to DeepMD\n")
    f.write('-'*50 + '\n')
    f.write("No. of Elements   :" + f'{nspecies}'+ '\n')
    f.write("Elements involved :" + f'{list(set(allatoms_AIMD))}'+ '\n')
    f.write("All Elements      :" + f'{atom_types}'+ '\n')
    f.write("No. of atoms      :" + f'{natoms}'+ '\n')
    f.write("No. of frames     :" + f'{Force_AIMD.shape[0]}'+ '\n')
    f.write("force.raw         :" + f'{Force_AIMD.shape}'+ '\n')
    f.write("coord.raw         :" + f'{Coord_AIMD.shape}'+ '\n')
    f.write("energy.raw        :" + f'{Etot_AIMD.shape}'+ '\n')
    f.write("box.raw           :" + f'{Lattice_AIMD.shape}'+ '\n')
#     f.write("virial.raw        :" + f'{Stress_AIMD.shape}'+ '\n')
    f.write('-'*50)
    
# Cleaning up 
os.system(f'mv -f *.raw conversionInfo.dat {folder}')
# Out:
# !!!Converting the AIMD data!!!
# --------------------------------------------------
# >Force, Energy, Coordinate, Lattice converted, shuffled, and saved
# Co: 32 Si: 32 O: 0
# Co: 32 Si: 32 O: 0
# # Summary of jdftx to DeepMD
#
# --------------------------------------------------
# No. of Elements   : 2
# Elements involved : ['Co', 'Si']
# All Elements      : ['Co', 'Si', 'O']
# No. of atoms      : 64
# No. of frames     : 411
# force.raw         : (411, 192)
# coord.raw         : (411, 192)
# energy.raw        : (411,)
# box.raw           : (411, 9)
# --------------------------------------------------
# 0

# %%
# Check if directory exists. If not, create it.
if os.path.exists(f'{folder}/training_data'):
    os.system(f'rm -r {folder}/training_data')
    
if os.path.exists(f'{folder}/validation_data'):
    os.system(f'rm -r {folder}/validation_data')

if not os.path.exists(f'{folder}/training_data'):
    os.makedirs(f'{folder}/training_data')
    print(f"'training_data' has been created.")

if not os.path.exists(f'{folder}/validation_data'):
    os.makedirs(f'{folder}/validation_data')
    print(f"'validation_data' has been created.")

# Copying the type.raw and type_map.raw to training_data and validation_data
os.system(f'cp {folder}/type* {folder}/training_data')
os.system(f'cp {folder}/type* {folder}/validation_data')


n_sets = int(Etot_AIMD.shape[0] // 4.5)

os.system(f'cd {folder}; /root/DeepMD_tutorial/deepmd-kit/data/raw/raw_to_set.sh {n_sets}')

os.system(f'mv {folder}/set.000 {folder}/validation_data')
os.system(f'mv {folder}/set.* {folder}/training_data')
# Out:
# 'training_data' has been created.
# 'validation_data' has been created.
# nframe is 411
# nline per set is 91
# will make 5 sets
# making set 0 ...
# making set 1 ...
# making set 2 ...
# making set 3 ...
# making set 4 ...
# 0

# %%
filename = 'md.o1065264'

dF_cutoff = -1e-05
with open(filename) as file:
    lines = file.readlines()
    
    # Extracting the section of electronic minimization:
    Emin_ini = []
    Emin_fin = []
    for i, line in enumerate(lines):
        if "Electronic minimization" in line:
            Emin_ini.append(i)
        if "Setting wave functions to eigenvectors of Hamiltonian" in line:
            Emin_fin.append(i)
    
    print(len(Emin_ini), len(Emin_fin))
    # Checking convergence with given dF:
    if len(Emin_ini) > 0 and len(Emin_fin) > 0:
        
        conv_Emin_ini = []
        conv_Emin_fin = []
        
        # Looping over all electronic minimization:
        for j in range(len(Emin_ini)):
            print('j', j)
            
            # Looping within the given range to append dF values:
            dF_values = []

            
            for k in range(Emin_ini[j], Emin_fin[j]):
#                 print(Emin_ini[j], Emin_fin[j], k)
                if "dF:" in lines[k]:
#                     print(lines[k])
#                     Extract the dF value from the line
                    dF = float(lines[k].split("dF: ")[1].split()[0])
#                     print(dF)
                    dF_values.append(dF)

            new_dF_values = dF_values
#             print("last dF values:", new_dF_values[-1])
            
            if new_dF_values:                                     
                last_dF = new_dF_values[-1]
                print("last dF values:", new_dF_values[-1])
                if float(last_dF) < -1e-05:
                    print("AIMD converged")
                    conv_Emin_ini.append(Emin_ini[j])
                    conv_Emin_fin.append(Emin_fin[j])
                else:
                    print("AIMD not converged")
#                 plt.plot(j, last_dF, '*r')
#                 plt.show()
print(conv_Emin_ini, conv_Emin_fin)
# Out:
# 319 318
# j 0
# last dF values: -1.23e-06
# AIMD not converged
# j 1
# last dF values: -0.0006407
# AIMD converged
# j 2
# last dF values: 0.0007364
# AIMD not converged
# j 3
# last dF values: 0.0001145
# AIMD not converged
# j 4
# last dF values: -0.0005756
# AIMD converged
# j 5
# last dF values: 0.0004978
# AIMD not converged
# j 6
# last dF values: 0.001536
# AIMD not converged
# j 7
# last dF values: -0.00255
# AIMD converged
# j 8
# last dF values: 0.001342
# AIMD not converged
# j 9
# last dF values: 9.027e-05
# AIMD not converged
# j 10
# last dF values: -0.000262
# AIMD converged
# j 11
# last dF values: -0.002171
# AIMD converged
# j 12
# last dF values: -5.948e-05
# AIMD converged
# j 13
# last dF values: 0.0005374
# AIMD not converged
# j 14
# last dF values: -0.001061
# AIMD converged
# j 15
# last dF values: 0.0002094
# AIMD not converged
# j 16
# last dF values: 0.004561
# AIMD not converged
# j 17
# last dF values: -0.002356
# AIMD converged
# j 18
# last dF values: 0.000218
# AIMD not converged
# j 19
# last dF values: -0.0008187
# AIMD converged
# j 20
# last dF values: -0.001045
# AIMD converged
# j 21
# last dF values: -0.000275
# AIMD converged
# j 22
# last dF values: -0.0005217
# AIMD converged
# j 23
# last dF values: -0.0006089
# AIMD converged
# j 24
# last dF values: -0.0005528
# AIMD converged
# j 25
# last dF values: 3.17e-05
# AIMD not converged
# j 26
# last dF values: -0.0003449
# AIMD converged
# j 27
# last dF values: -0.001908
# AIMD converged
# j 28
# last dF values: -0.0001073
# AIMD converged
# j 29
# last dF values: -0.0003602
# AIMD converged
# j 30
# last dF values: -0.000279
# AIMD converged
# j 31
# last dF values: -0.0001885
# AIMD converged
# j 32
# last dF values: -0.0005614
# AIMD converged
# j 33
# last dF values: -0.0002861
# AIMD converged
# j 34
# last dF values: -0.0009351
# AIMD converged
# j 35
# last dF values: 0.0002324
# AIMD not converged
# j 36
# last dF values: 0.0003071
# AIMD not converged
# j 37
# last dF values: -3.532e-07
# AIMD not converged
# j 38
# last dF values: -0.0002888
# AIMD converged
# j 39
# last dF values: -0.0001585
# AIMD converged
# j 40
# last dF values: 0.0002567
# AIMD not converged
# j 41
# last dF values: -1.219e-05
# AIMD converged
# j 42
# last dF values: -0.0001432
# AIMD converged
# j 43
# last dF values: 0.000123
# AIMD not converged
# j 44
# last dF values: 7.746e-05
# AIMD not converged
# j 45
# last dF values: 0.0004647
# AIMD not converged
# j 46
# last dF values: 0.003013
# AIMD not converged
# j 47
# last dF values: 0.0003232
# AIMD not converged
# j 48
# last dF values: -7.284e-05
# AIMD converged
# j 49
# last dF values: -0.0004188
# AIMD converged
# j 50
# last dF values: -0.0003387
# AIMD converged
# j 51
# last dF values: -0.0006188
# AIMD converged
# j 52
# last dF values: 2.613e-05
# AIMD not converged
# j 53
# last dF values: -0.0003007
# AIMD converged
# j 54
# last dF values: 0.0001192
# AIMD not converged
# j 55
# last dF values: -6.376e-05
# AIMD converged
# j 56
# last dF values: -0.0002483
# AIMD converged
# j 57
# last dF values: -0.0001296
# AIMD converged
# j 58
# last dF values: -4.162e-05
# AIMD converged
# j 59
# last dF values: 6.116e-05
# AIMD not converged
# j 60
# last dF values: -0.0002691
# AIMD converged
# j 61
# last dF values: -0.000745
# AIMD converged
# j 62
# last dF values: 0.0001095
# AIMD not converged
# j 63
# last dF values: 0.0001251
# AIMD not converged
# j 64
# last dF values: -0.0003971
# AIMD converged
# j 65
# last dF values: 0.0001207
# AIMD not converged
# j 66
# last dF values: -0.0001349
# AIMD converged
# j 67
# last dF values: 0.0004635
# AIMD not converged
# j 68
# last dF values: -4.397e-05
# AIMD converged
# j 69
# last dF values: 0.0003127
# AIMD not converged
# j 70
# last dF values: -2.242e-05
# AIMD converged
# j 71
# last dF values: 0.0002681
# AIMD not converged
# j 72
# last dF values: -0.000101
# AIMD converged
# j 73
# last dF values: -0.0001031
# AIMD converged
# j 74
# last dF values: -0.0004208
# AIMD converged
# j 75
# last dF values: -0.0001183
# AIMD converged
# j 76
# last dF values: -0.0002853
# AIMD converged
# j 77
# last dF values: -0.0005376
# AIMD converged
# j 78
# last dF values: -0.0007107
# AIMD converged
# j 79
# last dF values: -2.769e-05
# AIMD converged
# j 80
# last dF values: 2.678e-05
# AIMD not converged
# j 81
# last dF values: 0.0002712
# AIMD not converged
# j 82
# last dF values: 0.0002959
# AIMD not converged
# j 83
# last dF values: 0.0003304
# AIMD not converged
# j 84
# last dF values: 0.0005444
# AIMD not converged
# j 85
# last dF values: 0.001309
# AIMD not converged
# j 86
# last dF values: 0.001544
# AIMD not converged
# j 87
# last dF values: 0.001639
# AIMD not converged
# j 88
# last dF values: 0.001066
# AIMD not converged
# j 89
# last dF values: 0.000191
# AIMD not converged
# j 90
# last dF values: -0.003141
# AIMD converged
# j 91
# last dF values: 0.001596
# AIMD not converged
# j 92
# last dF values: 0.001077
# AIMD not converged
# j 93
# last dF values: 0.0003304
# AIMD not converged
# j 94
# last dF values: 0.0007752
# AIMD not converged
# j 95
# last dF values: 0.0008818
# AIMD not converged
# j 96
# last dF values: 0.003707
# AIMD not converged
# j 97
# last dF values: 0.0007224
# AIMD not converged
# j 98
# last dF values: 0.001501
# AIMD not converged
# j 99
# last dF values: -0.0002422
# AIMD converged
# j 100
# last dF values: 0.001033
# AIMD not converged
# j 101
# last dF values: 0.0006547
# AIMD not converged
# j 102
# last dF values: 0.0009311
# AIMD not converged
# j 103
# last dF values: 0.000896
# AIMD not converged
# j 104
# last dF values: -1.521e-05
# AIMD converged
# j 105
# last dF values: -0.0001226
# AIMD converged
# j 106
# last dF values: 0.0007168
# AIMD not converged
# j 107
# last dF values: 0.0002985
# AIMD not converged
# j 108
# last dF values: -0.001865
# AIMD converged
# j 109
# last dF values: -0.0008245
# AIMD converged
# j 110
# last dF values: 8.022e-06
# AIMD not converged
# j 111
# last dF values: 0.005358
# AIMD not converged
# j 112
# last dF values: -0.0008024
# AIMD converged
# j 113
# last dF values: -0.0003949
# AIMD converged
# j 114
# last dF values: 0.0001386
# AIMD not converged
# j 115
# last dF values: -0.0005586
# AIMD converged
# j 116
# last dF values: 0.000274
# AIMD not converged
# j 117
# last dF values: -0.002754
# AIMD converged
# j 118
# last dF values: -0.01411
# AIMD converged
# j 119
# last dF values: -0.000768
# AIMD converged
# j 120
# last dF values: -4.481e-05
# AIMD converged
# j 121
# last dF values: 9.456e-05
# AIMD not converged
# j 122
# last dF values: -0.0001804
# AIMD converged
# j 123
# last dF values: -1.674e-05
# AIMD converged
# j 124
# last dF values: 0.0001146
# AIMD not converged
# j 125
# last dF values: 5.368e-05
# AIMD not converged
# j 126
# last dF values: -0.0001003
# AIMD converged
# j 127
# last dF values: -0.0003813
# AIMD converged
# j 128
# last dF values: -0.001016
# AIMD converged
# j 129
# last dF values: -0.001264
# AIMD converged
# j 130
# last dF values: -0.0001095
# AIMD converged
# j 131
# last dF values: -0.0002824
# AIMD converged
# j 132
# last dF values: 4.413e-06
# AIMD not converged
# j 133
# last dF values: -0.000826
# AIMD converged
# j 134
# last dF values: 0.0003329
# AIMD not converged
# j 135
# last dF values: 0.00194
# AIMD not converged
# j 136
# last dF values: 0.0006383
# AIMD not converged
# j 137
# last dF values: -0.0002112
# AIMD converged
# j 138
# last dF values: -4.131e-05
# AIMD converged
# j 139
# last dF values: -0.0007882
# AIMD converged
# j 140
# last dF values: -0.0002936
# AIMD converged
# j 141
# last dF values: -9.979e-05
# AIMD converged
# j 142
# last dF values: -0.0008775
# AIMD converged
# j 143
# last dF values: -0.0003866
# AIMD converged
# j 144
# last dF values: -9.347e-06
# AIMD not converged
# j 145
# last dF values: -5.986e-05
# AIMD converged
# j 146
# last dF values: 0.0007356
# AIMD not converged
# j 147
# last dF values: -0.0007833
# AIMD converged
# j 148
# last dF values: 0.0004452
# AIMD not converged
# j 149
# last dF values: 0.0003671
# AIMD not converged
# j 150
# last dF values: 0.000647
# AIMD not converged
# j 151
# last dF values: 0.0004765
# AIMD not converged
# j 152
# last dF values: -0.0001932
# AIMD converged
# j 153
# last dF values: -0.0002827
# AIMD converged
# j 154
# last dF values: -4.236e-05
# AIMD converged
# j 155
# last dF values: 0.0004549
# AIMD not converged
# j 156
# last dF values: 0.0003953
# AIMD not converged
# j 157
# last dF values: 0.0003771
# AIMD not converged
# j 158
# last dF values: -0.003594
# AIMD converged
# j 159
# last dF values: -0.0001465
# AIMD converged
# j 160
# last dF values: 0.0001399
# AIMD not converged
# j 161
# last dF values: 0.0003519
# AIMD not converged
# j 162
# last dF values: -0.006975
# AIMD converged
# j 163
# last dF values: 0.001293
# AIMD not converged
# j 164
# last dF values: -2.375e-05
# AIMD converged
# j 165
# last dF values: -4.514e-06
# AIMD not converged
# j 166
# last dF values: 0.004307
# AIMD not converged
# j 167
# last dF values: -0.009347
# AIMD converged
# j 168
# last dF values: -0.0001962
# AIMD converged
# j 169
# last dF values: 0.0001521
# AIMD not converged
# j 170
# last dF values: -0.0008176
# AIMD converged
# j 171
# last dF values: 0.0003803
# AIMD not converged
# j 172
# last dF values: -0.0001213
# AIMD converged
# j 173
# last dF values: 5.364e-05
# AIMD not converged
# j 174
# last dF values: -0.0002856
# AIMD converged
# j 175
# last dF values: -0.0001949
# AIMD converged
# j 176
# last dF values: -0.0001674
# AIMD converged
# j 177
# last dF values: -0.0004955
# AIMD converged
# j 178
# last dF values: -0.0003306
# AIMD converged
# j 179
# last dF values: -0.0002407
# AIMD converged
# j 180
# last dF values: -0.0008062
# AIMD converged
# j 181
# last dF values: -4.905e-05
# AIMD converged
# j 182
# last dF values: 0.000112
# AIMD not converged
# j 183
# last dF values: 0.001078
# AIMD not converged
# j 184
# last dF values: 0.000437
# AIMD not converged
# j 185
# last dF values: 0.0001152
# AIMD not converged
# j 186
# last dF values: 6.233e-05
# AIMD not converged
# j 187
# last dF values: -0.0004786
# AIMD converged
# j 188
# last dF values: -0.0004405
# AIMD converged
# j 189
# last dF values: -0.0005993
# AIMD converged
# j 190
# last dF values: -0.0006859
# AIMD converged
# j 191
# last dF values: -0.0003334
# AIMD converged
# j 192
# last dF values: -0.0005191
# AIMD converged
# j 193
# last dF values: -0.0005491
# AIMD converged
# j 194
# last dF values: -0.0003725
# AIMD converged
# j 195
# last dF values: -0.0006147
# AIMD converged
# j 196
# last dF values: -0.0007437
# AIMD converged
# j 197
# last dF values: -0.0008642
# AIMD converged
# j 198
# last dF values: -0.0003705
# AIMD converged
# j 199
# last dF values: -0.0002192
# AIMD converged
# j 200
# last dF values: -0.0001204
# AIMD converged
# j 201
# last dF values: -0.0002987
# AIMD converged
# j 202
# last dF values: -9.359e-05
# AIMD converged
# j 203
# last dF values: -0.0001947
# AIMD converged
# j 204
# last dF values: -0.0003381
# AIMD converged
# j 205
# last dF values: -0.0006229
# AIMD converged
# j 206
# last dF values: -0.0002845
# AIMD converged
# j 207
# last dF values: -1.037e-05
# AIMD converged
# j 208
# last dF values: -0.0003024
# AIMD converged
# j 209
# last dF values: -0.0002273
# AIMD converged
# j 210
# last dF values: -0.0005066
# AIMD converged
# j 211
# last dF values: -0.0001545
# AIMD converged
# j 212
# last dF values: -0.0003659
# AIMD converged
# j 213
# last dF values: -0.0004209
# AIMD converged
# j 214
# last dF values: -0.000261
# AIMD converged
# j 215
# last dF values: -0.0002142
# AIMD converged
# j 216
# last dF values: -9.222e-05
# AIMD converged
# j 217
# last dF values: 0.000121
# AIMD not converged
# j 218
# last dF values: 0.0003676
# AIMD not converged
# j 219
# last dF values: -0.000129
# AIMD converged
# j 220
# last dF values: -0.0008083
# AIMD converged
# j 221
# last dF values: -0.0002243
# AIMD converged
# j 222
# last dF values: -0.0005531
# AIMD converged
# j 223
# last dF values: -0.0003009
# AIMD converged
# j 224
# last dF values: -0.001072
# AIMD converged
# j 225
# last dF values: -0.000979
# AIMD converged
# j 226
# last dF values: -0.0003899
# AIMD converged
# j 227
# last dF values: -0.0002114
# AIMD converged
# j 228
# last dF values: -0.0001395
# AIMD converged
# j 229
# last dF values: -0.001042
# AIMD converged
# j 230
# last dF values: -0.0002367
# AIMD converged
# j 231
# last dF values: -2.006e-05
# AIMD converged
# j 232
# last dF values: -0.0005513
# AIMD converged
# j 233
# last dF values: -0.0001548
# AIMD converged
# j 234
# last dF values: -0.000103
# AIMD converged
# j 235
# last dF values: -0.0003424
# AIMD converged
# j 236
# last dF values: -3.698e-05
# AIMD converged
# j 237
# last dF values: -8.752e-05
# AIMD converged
# j 238
# last dF values: -1.118e-05
# AIMD converged
# j 239
# last dF values: -0.0001493
# AIMD converged
# j 240
# last dF values: -0.0001629
# AIMD converged
# j 241
# last dF values: -0.000334
# AIMD converged
# j 242
# last dF values: 1.92e-06
# AIMD not converged
# j 243
# last dF values: -0.0006081
# AIMD converged
# j 244
# last dF values: -0.0003009
# AIMD converged
# j 245
# last dF values: -0.0001857
# AIMD converged
# j 246
# last dF values: -4.488e-05
# AIMD converged
# j 247
# last dF values: -0.0002256
# AIMD converged
# j 248
# last dF values: -0.0008588
# AIMD converged
# j 249
# last dF values: 0.0001664
# AIMD not converged
# j 250
# last dF values: 0.0007139
# AIMD not converged
# j 251
# last dF values: -3.445e-05
# AIMD converged
# j 252
# last dF values: -0.0003877
# AIMD converged
# j 253
# last dF values: -0.0007608
# AIMD converged
# j 254
# last dF values: -7.986e-05
# AIMD converged
# j 255
# last dF values: -0.0002617
# AIMD converged
# j 256
# last dF values: -8.411e-05
# AIMD converged
# j 257
# last dF values: -1.171e-05
# AIMD converged
# j 258
# last dF values: -5.268e-05
# AIMD converged
# j 259
# last dF values: -0.0001244
# AIMD converged
# j 260
# last dF values: 0.0003386
# AIMD not converged
# j 261
# last dF values: -0.0001054
# AIMD converged
# j 262
# last dF values: 2.458e-05
# AIMD not converged
# j 263
# last dF values: -0.001119
# AIMD converged
# j 264
# last dF values: -0.002063
# AIMD converged
# j 265
# last dF values: -0.0003381
# AIMD converged
# j 266
# last dF values: -0.00486
# AIMD converged
# j 267
# last dF values: -0.00105
# AIMD converged
# j 268
# last dF values: -0.003661
# AIMD converged
# j 269
# last dF values: -0.0007721
# AIMD converged
# j 270
# last dF values: 0.002744
# AIMD not converged
# j 271
# last dF values: 0.0003548
# AIMD not converged
# j 272
# last dF values: 0.0001685
# AIMD not converged
# j 273
# last dF values: -0.007078
# AIMD converged
# j 274
# last dF values: 0.004742
# AIMD not converged
# j 275
# last dF values: -0.004975
# AIMD converged
# j 276
# last dF values: -0.006894
# AIMD converged
# j 277
# last dF values: 0.04664
# AIMD not converged
# j 278
# last dF values: -3.569
# AIMD converged
# j 279
# last dF values: 1.31
# AIMD not converged
# j 280
# last dF values: -0.0002089
# AIMD converged
# j 281
# last dF values: 0.1322
# AIMD not converged
# j 282
# last dF values: -2.162
# AIMD converged
# j 283
# last dF values: 0.04288
# AIMD not converged
# j 284
# last dF values: -0.5415
# AIMD converged
# j 285
# last dF values: -1.753
# AIMD converged
# j 286
# last dF values: -0.2471
# AIMD converged
# j 287
# last dF values: -0.426
# AIMD converged
# j 288
# last dF values: -2.139
# AIMD converged
# j 289
# last dF values: -5.229
# AIMD converged
# j 290
# last dF values: -0.149
# AIMD converged
# j 291
# last dF values: -0.3076
# AIMD converged
# j 292
# last dF values: 0.01586
# AIMD not converged
# j 293
# last dF values: 0.008228
# AIMD not converged
# j 294
# last dF values: -0.1316
# AIMD converged
# j 295
# last dF values: 0.4109
# AIMD not converged
# j 296
# last dF values: -0.3204
# AIMD converged
# j 297
# last dF values: 3.416
# AIMD not converged
# j 298
# last dF values: 0.01256
# AIMD not converged
# j 299
# last dF values: -0.2408
# AIMD converged
# j 300
# last dF values: -0.02583
# AIMD converged
# j 301
# last dF values: 0.07536
# AIMD not converged
# j 302
# last dF values: 0.3856
# AIMD not converged
# j 303
# last dF values: -0.1934
# AIMD converged
# j 304
# last dF values: -0.01789
# AIMD converged
# j 305
# last dF values: 0.01216
# AIMD not converged
# j 306
# last dF values: 0.1482
# AIMD not converged
# j 307
# last dF values: -0.402
# AIMD converged
# j 308
# last dF values: -0.5329
# AIMD converged
# j 309
# last dF values: 0.1115
# AIMD not converged
# j 310
# last dF values: 0.07712
# AIMD not converged
# j 311
# last dF values: -0.2319
# AIMD converged
# j 312
# last dF values: 0.337
# AIMD not converged
# j 313
# last dF values: -0.459
# AIMD converged
# j 314
# last dF values: -2.257e-05
# AIMD converged
# j 315
# last dF values: -1.575
# AIMD converged
# j 316
# last dF values: -0.3743
# AIMD converged
# j 317
# last dF values: 0.1757
# AIMD not converged
# j 318
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [93], in <cell line: 4>()
#      27             # Looping within the given range to append dF values:
#      28             dF_values = []
# ---> 31             for k in range(Emin_ini[j], Emin_fin[j]):
#      32 #                 print(Emin_ini[j], Emin_fin[j], k)
#      33                 if "dF:" in lines[k]:
#      34 #                     print(lines[k])
#      35 #                     Extract the dF value from the line
#      36                     dF = float(lines[k].split("dF: ")[1].split()[0])
#
# IndexError: list index out of range

# %%
                if new_dF_values:                                     
                    min_dF = min(new_dF_values)
                    print("Smallest dF value:", min_dF)
                    if min_dF > 1e-05:
                        print("The smallest dF value is larger than 1e-05.")
                    else:
                        print("The smallest dF value is not larger than 1e-05.")

# %%
                if "dF: " in lines[i]:
                    # Extract the dF value from the line
                    dF = float(lines[i].split("dF: ")[1].split()[0])
                    dF_values.append(dF)
                
                new_dF_values = np.abs(dF_values)
                print("dF values:", new_dF_values)

# %%
if -2e-2 < -1e-1:
    print("true")
else:
    print("false")
# Out:
# false

# %%
np.linspace(2, 10, 10-2)
# Out:
# array([ 2.        ,  3.14285714,  4.28571429,  5.42857143,  6.57142857,
#         7.71428571,  8.85714286, 10.        ])

# %%
float(-2e-6)
# Out:
# -2e-06

# %%
float(-1e-6)
# Out:
# -0.1

# %%
x= [ 16.6195, -0.873218, -1.23946 ]
y= [ -0.861317, 19.2448, -2.15625 ]
z= [ -0.702846, -1.04136, 39.4966 ]

box = np.zeros((3,3))
box[0, :] = np.array(x)
box[1, :] = np.array(y)
box[2, :] = np.array(z)
box_corr = box.T
x_corr = (box_corr[0, :]*len_conv).tolist()
y_corr = (box_corr[1, :]*len_conv).tolist()
z_corr = (box_corr[2, :]*len_conv).tolist()

print(box_corr)
print(box)
print(x_corr, '\n', y_corr, '\n', z_corr)
x_corr + y_corr + z_corr
# Out:
# [[16.6195   -0.861317 -0.702846]
#  [-0.873218 19.2448   -1.04136 ]
#  [-1.23946  -2.15625  39.4966  ]]
# [[16.6195   -0.873218 -1.23946 ]
#  [-0.861317 19.2448   -2.15625 ]
#  [-0.702846 -1.04136  39.4966  ]]
# [8.7946571515, -0.455789146109, -0.371929937742]
#  [-0.46208688158600003, 10.1839055296, -0.5510637607200001]
#  [-0.65589372442, -1.14103790625, 20.9006922982]
# [8.7946571515,
#  -0.455789146109,
#  -0.371929937742,
#  -0.46208688158600003,
#  10.1839055296,
#  -0.5510637607200001,
#  -0.65589372442,
#  -1.14103790625,
#  20.9006922982]

# %%
# Out:
# [8.7946571515, -0.46208688158600003, -0.65589372442]
#  [-0.455789146109, 10.1839055296, -1.14103790625]
#  [-0.371929937742, -0.5510637607200001, 20.9006922982]

# %%
# Out:
# [8.7946571515, -0.46208688158600003, -0.65589372442]
